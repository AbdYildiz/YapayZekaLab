# %%
#6
ip = input("Lutfen ip adresinizi giriniz: ").split(".")
ip[0] = int(ip[0])
ip[1] = int(ip[1])
ip[2] = int(ip[2])
ip[3] = int(ip[3])

for i in range(10):
    ip[3] +=1
    print(ip)
    
    if(ip[3] >= 255):
        ip[2] +=1
        ip[3] = 0
        if(ip[2] >= 256):
            ip[1] +=1
            ip[2] = 0
            if(ip[1] >= 256):
                ip[0] +=1
                ip[1] = 0
                if(ip[0] >= 256):
                    break
# Out:
# Lutfen ip adresinizi giriniz:  192.168.255.252
# [192, 168, 255, 253]
# [192, 168, 255, 254]
# [192, 168, 255, 255]
# [192, 169, 0, 1]
# [192, 169, 0, 2]
# [192, 169, 0, 3]
# [192, 169, 0, 4]
# [192, 169, 0, 5]
# [192, 169, 0, 6]
# [192, 169, 0, 7]
# [192, 169, 0, 8]
# [192, 169, 0, 9]
# [192, 169, 0, 10]
# [192, 169, 0, 11]
# [192, 169, 0, 12]
# [192, 169, 0, 13]
# [192, 169, 0, 14]
# [192, 169, 0, 15]
# [192, 169, 0, 16]
# [192, 169, 0, 17]
# [192, 169, 0, 18]
# [192, 169, 0, 19]
# [192, 169, 0, 20]
# [192, 169, 0, 21]
# [192, 169, 0, 22]
# [192, 169, 0, 23]
# [192, 169, 0, 24]
# [192, 169, 0, 25]
# [192, 169, 0, 26]
# [192, 169, 0, 27]
# [192, 169, 0, 28]
# [192, 169, 0, 29]
# [192, 169, 0, 30]
# [192, 169, 0, 31]
# [192, 169, 0, 32]
# [192, 169, 0, 33]
# [192, 169, 0, 34]
# [192, 169, 0, 35]
# [192, 169, 0, 36]
# [192, 169, 0, 37]
# [192, 169, 0, 38]
# [192, 169, 0, 39]
# [192, 169, 0, 40]
# [192, 169, 0, 41]
# [192, 169, 0, 42]
# [192, 169, 0, 43]
# [192, 169, 0, 44]
# ...
